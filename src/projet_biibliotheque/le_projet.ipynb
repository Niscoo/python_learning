# %% [markdown]
# ## 📚 PROJET : SYSTÈME DE GESTION DE BIBLIOTHÈQUE INTELLIGENTE (PYTHON)

# %% [markdown]
# ### 🎯 Objectif général

# %% [markdown]
# Ce projet a pour objectif de vous entraîner à :
#
# utiliser efficacement les structures de données en Python ;
#
# organiser un programme en plusieurs modules ;
#
# appliquer une logique algorithmique cohérente ;
#
# écrire un code lisible, robuste et maintenable.
#
# Le projet doit être réalisé en Python, en ligne de commande, sans interface graphique.

# %% [markdown]
# ### 🔹 CONSIGNES GÉNÉRALES

# %% [markdown]
# -Utilisez uniquement la bibliothèque standard de Python.
#
# -Le projet doit être découpé en fichiers cohérents.
#
# -Toute donnée doit être stockée dans une structure de données adaptée.
#
# -Le programme doit gérer les erreurs et cas limites.
#
# -Le code doit être commenté et structuré.

# %% [markdown]
# ### 🧩 PARTIE 1 – MODÉLISATION DES DONNÉES

# %% [markdown]
#     1.Représentez les livres de la bibliothèque.
#
# Chaque livre doit posséder un ISBN unique, un titre, un auteur, une catégorie et un état de disponibilité.
#
# Les livres doivent être stockés dans une structure permettant un accès rapide par ISBN.
#
#     2.Représentez les utilisateurs.
#
# Chaque utilisateur doit avoir un identifiant unique, un nom et un historique d’emprunts.
#
# Un utilisateur peut emprunter plusieurs livres simultanément.
#
#     3.Représentez les emprunts.
#
# Un emprunt doit contenir l’identifiant de l’utilisateur, l’ISBN du livre et la date d’emprunt.
#
# L’historique des emprunts doit être conservé.

# %% [markdown]
# ### 📘 PARTIE 2 – GESTION DES LIVRES

# %% [markdown]
#     4.Implémentez l’ajout d’un livre dans la bibliothèque.
#
# Refusez l’ajout si l’ISBN existe déjà.
#
# Affichez un message d’erreur clair.
#
#     5.Implémentez la suppression d’un livre.
#
# Interdisez la suppression d’un livre actuellement emprunté.
#
# Gérez correctement les erreurs.
#
#     6.Implémentez la recherche de livres :
#
# par ISBN ;
#
# par titre (recherche partielle) ;
#
# par auteur ;
#
# par catégorie.
#
#     7.Implémentez l’affichage :
#
# de tous les livres ;
#
# uniquement des livres disponibles ;
#
# uniquement des livres empruntés.

# %% [markdown]
# ### 👤 PARTIE 3 – GESTION DES UTILISATEURS

# %% [markdown]
#     8.Implémentez l’ajout d’un utilisateur.
#
# Générez automatiquement un identifiant unique.
#
#     9.Implémentez la suppression d’un utilisateur.
#
# Interdisez la suppression si l’utilisateur a des emprunts en cours.
#
#     10.Implémentez l’affichage des informations d’un utilisateur :
#
# livres actuellement empruntés ;
#
# historique des emprunts.

# %% [markdown]
# ### 🔄 PARTIE 4 – EMPRUNTS ET RETOURS

# %% [markdown]
#     11.Implémentez l’emprunt d’un livre.
#
# Vérifiez l’existence du livre et de l’utilisateur.
#
# Vérifiez la disponibilité du livre.
#
# Enregistrez la date d’emprunt.
#
#     12.Implémentez le retour d’un livre.
#
# Vérifiez que le livre est bien emprunté par l’utilisateur.
#
# Mettez à jour l’état du livre et de l’utilisateur.
#
#     13.Conservez l’historique des emprunts dans une structure adaptée, respectant l’ordre chronologique.

# %% [markdown]
# ### ⏳ PARTIE 5 – FILE D’ATTENTE ET PRIORITÉ

# %% [markdown]
#     14.Que se passe-t-il lorsqu’un livre n’est plus disponible ?
#
# Comment mettre en place une file d’attente pour les réservations ?
#
# Quelle structure de données est la plus adaptée ?
#
#     15.Comment attribuer le livre au prochain utilisateur lorsque celui-ci est rendu ?
#
# Comment notifier implicitement l’utilisateur suivant ?
#
# Que faire si l’utilisateur ne souhaite plus le livre ?

# %% [markdown]
# ### 📊 PARTIE 6 – STATISTIQUES ET ANALYSE

# %% [markdown]
#     16.Calculez et affichez :
#
# les livres les plus empruntés ;
#
# les auteurs les plus populaires ;
#
# les catégories les plus empruntées.
#
#     17.Identifiez les utilisateurs les plus actifs.
#
#     18.Utilisez des ensembles (set) pour gérer les auteurs et catégories uniques.

# %% [markdown]
# ### 🧠 PARTIE 7 – LOGIQUE AVANCÉE

# %% [markdown]
#     19.Comment recommander un livre à un utilisateur ?
#
# En fonction des catégories déjà empruntées
#
# En fonction des livres populaires
#
#     20.Comment gérer les erreurs et les cas limites ?
#
# Emprunt impossible
#
# Livre inexistant
#
# Utilisateur inconnu

# %% [markdown]
# ### 🧪 PARTIE 8 – TESTS ET QUALITÉ DU CODE

# %% [markdown]
#     21.Découpez le projet en modules distincts.
#
#     22.Évitez la duplication de code.
#
#     23.Documentez chaque fonction.
#
#     24.Structurez clairement le point d’entrée du programme (main.py).

# %% [markdown]
# ### 🌟 BONUS (FACULTATIF)

# %% [markdown]
# Sauvegardez les données dans des fichiers (JSON).
#
# Implémentez un système de pénalités pour retard.
#
# Ajoutez une limite maximale de livres empruntables par utilisateur.

# %% [markdown]
# ✅ CRITÈRES D’ÉVALUATION
#
# Pertinence des structures de données
#
# Qualité du code et lisibilité
#
# Gestion des erreurs
#
# Respect des consignes
#
# Modularité du projet
